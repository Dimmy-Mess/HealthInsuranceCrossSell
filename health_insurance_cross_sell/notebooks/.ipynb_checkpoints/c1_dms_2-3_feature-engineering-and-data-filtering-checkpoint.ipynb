# %% [markdown]
# ## 0. Imports, Paths and Helper Functions

# %% [markdown]
# ### 0.1 Imports

# %%
import numpy             as np
import pandas            as pd
import seaborn           as sns
import matplotlib.pyplot as plt


from IPython.core.display  import HTML
from IPython.display       import Image

# %% [markdown]
# ### 0.2 Paths

# %%
data = '../data/'
raw  = 'raw/'
interim = 'interim/'

images_path = '../reports/figures/'

# %% [markdown]
# ### 0.3 Helper Functions

# %%
def jupyter_settings():
    # %matplotlib inline
    # %pylab inline
    
    plt.style.use( 'bmh' )
    plt.rcParams['figure.figsize'] = [25, 12]
    plt.rcParams['font.size'] = 24
    
    display( HTML( '<style>.container { width:100% !important; }</style>') )
    pd.options.display.max_columns = None
    pd.options.display.max_rows = None
    pd.set_option( 'display.expand_frame_repr', False )
    
    sns.set()

# %%
jupyter_settings()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# ## 2 - Feature Engineering and Hypothesis Creation

# %%
df2 = pd.read_csv(data+raw+'crossel.csv')

# %% [markdown]
# ### 2.1 - Mind Map Hypothesis and Hypothesis Creation

# %%
Image(images_path+'mind_map.png')

# %% [markdown]
# **H1**- Clientes do gênero masculino estão mais interessados em adquirir o seguro;
#
# **H2**- Clientes que aportam um valor maior que a média de prêmio anual não estão interessados;
#
# **H3**- Clientes de certas regiões demonstram pouco ou nenhum interesse no seguro oferecido;
#
# **H4**- Existe uma correlação forte entre as regiões e os clientes segurados/interessados em seguro;
#
# **H5**- Clientes interessados são associados à empresa menor a um tempo menor ou igual a não interessados;
#
# **H6**- A idade média dos clientes interessados varia de acordo com a região;
#
# **H7**- A idade média dos clientes interessados no seguro é maior que os clientes não interessados;
#
# **H8**- Existe uma correlação entre os clientes interessados e o código anônimo;
#
# **H9**- Apenas clientes habilitados tem interesse no seguro;
#
# **H10**- Os clientes interessados no seguro, em sua maior parte, nunca danificaram seus veiculos;
#
# **H11**- Mais da metade dos clientes interessados no seguro tem um veículo a menos de 1 ano;
#
# **H12**- Regiões com o menor número de clientes segurados possuem menos interesse em adquirir o seguro;
#
# **H13**- A maior parte dos interessados não possui ainda um seguro de carro;

# %% [markdown]
# ### 2.2 - Feature Engineering

# %%
df2['vehicle_damage'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df2['vehicle_damage'] = df2['vehicle_damage'].apply(lambda x: 1 if x=="Yes" else 0)
df2['vehicle_age'] = df2['vehicle_age'].apply(lambda x: "over_2years" if x =="> 2 Years" else "between_12years" if x == "1-2 Year" else "below_year")
df2['gender'] = df2['gender'].apply(lambda x: x.lower())

# %%
df2.head()
# Out:
#    Unnamed: 0  id  gender  age  region_code  policy_sales_channel  driving_license      vehicle_age  vehicle_damage  previously_insured  annual_premium  vintage  response
# 0           0   7    male   23         11.0                 152.0                1       below_year               1                   0         23367.0      249         0
# 1           1  13  female   41         15.0                  14.0                1  between_12years               0                   1         31409.0      221         0
# 2           2  18  female   25         35.0                 152.0                1       below_year               0                   1         46622.0      299         0
# 3           3  31  female   26          8.0                 160.0                1       below_year               0                   0          2630.0      136         0
# 4           4  39    male   45          8.0                 124.0                1  between_12years               1                   0         42297.0      264         0

# %%
df2.to_csv(data+interim+'fe-filtering.csv')

# %% [markdown]
# ## ~3 - Data Filtering~ (Not in this CRISP cycle)
